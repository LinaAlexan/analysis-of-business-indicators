# %% [markdown]
# ------------

# %% [markdown]
# ## Анализ бизнес-показателей
# ### Шаг 1. Загрузите данные и подготовьте их к анализу
#
# - Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
# Пути к файлам
# /datasets/visits_info_short.csv. Скачать датасет;
# /datasets/orders_info_short.csv. Скачать датасет;
# /datasets/costs_info_short.csv. Скачать датасет.
# - Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.
# ### Шаг 2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# - Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
# Это функции для вычисления значений метрик:
# get_profiles() — для создания профилей пользователей,
# get_retention() — для подсчёта Retention Rate,
# get_conversion() — для подсчёта конверсии,
# get_ltv() — для подсчёта LTV.
# А также функции для построения графиков:
# filter_data() — для сглаживания данных,
# plot_retention() — для построения графика Retention Rate,
# plot_conversion() — для построения графика конверсии,
# plot_ltv_roi — для визуализации LTV и ROI.
# ### Шаг 3. Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
# - После каждого пункта сформулируйте выводы.
# ### Шаг 4. Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
# Напишите промежуточные выводы.
# ### Шаг 5. Оцените окупаемость рекламы
#
# - Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?
# - Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
# ### Шаг 6. Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
# импортируем библиотеки:
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import datetime
import math
import time
from datetime import datetime
from datetime import date, timedelta as td

# %%
# загружаем данные из csv- файлов:
visit = pd.read_csv('/datasets/visits_info_short.csv')
order = pd.read_csv('/datasets/orders_info_short.csv')
cost = pd.read_csv('/datasets/costs_info_short.csv')

# %%
# посмотрим на структуру датафреймов.
# Выведем первые 10 строк каждого, а так же структуру:
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
visit.head(10)
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %% [markdown]
# Даты в датафрейме (начало, окончание сессии) в виде строк,
# поэтому переведем их в формат даты и времени (к типу datetime).
# Переведем названия столбцов к нижнему регистру.
# Region, Device и Channel переведем в строковый тип данных:

# %%
visit['Region'] = visit['Region'].astype(str)
visit['Channel'] = visit['Channel'].astype(str)
visit['Device'] = visit['Device'].astype(str)

# %%
visit.columns = visit.columns.str.lower().str.replace(' ', '_')

# %%
#приводим столбцы session_start, session_end к типу даты и перепроверяем себя:
visit['session_start'] = pd.to_datetime(visit['session_start'])
visit['session_end'] = pd.to_datetime(visit['session_end'])
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# Еще немного поработаем с датафреймом visit. Проверим, есть ли явные дубликаты, а так же посмотрим на количество пропусков:

# %%
visit.duplicated().sum()
# Out:
# 0

# %%
 visit.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %% [markdown]
# Дупликатов и пропущенных значений не обнаружено.

# %% [markdown]
# Посмотрим, какие данные хранятся в датафрейме:
# - количество уникальных пользователей и как часто они фигурируют
# - сколько стран
# - какими устройствами пользуются пользователи
# - уникальные значения в канале привлечения:

# %%
visit['user_id'].value_counts()
# Out:
# 33606575057     46
# 943775408561    36
# 901180916748    35
# 870784569391    34
# 764086596354    33
#                 ..
# 350468480225     1
# 748123264144     1
# 909267360937     1
# 816252757222     1
# 425788122907     1
# Name: user_id, Length: 150008, dtype: int64

# %%
visit['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visit['device'].value_counts()
# Out:
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: device, dtype: int64

# %%
visit['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# - количество уникальных пользователей и как часто они фигурируют: уникальных пользователей 150008, по идентификатору пользователя мы видим, что самые частотные значения сессий от 46 раз до 33 сессий на уникального пользователя.
# - сколько стран: в датайфрейме данные о четрыех регионах: США, Франция, Великобритания, Германия.
# - какими устройствами пользуются пользователи: Среди устройств встречаются iPhone, Android, PC, Mac, но наболее популярен сервис у пользователей iPhone (112603), а наименее популярен Mac(62022)
# - уникальные значения в канале привлечения: визуализировали каналы привлечения пользователей (11 каналов), вероятно это ключевая информация, с которой дальше предстоит работа.

# %% [markdown]
# Посмотрим на характеристики начала/конца сессий:

# %%
visit['session_start'].count()
# Out:
# 309901

# %%
visit['session_end'].count()
# Out:
# 309901

# %%
visit['session_start'].value_counts()
# Out:
# 2019-06-27 14:56:41    3
# 2019-10-10 22:50:07    3
# 2019-08-24 12:06:37    3
# 2019-10-22 17:17:39    3
# 2019-10-26 12:40:03    3
#                       ..
# 2019-05-26 12:24:05    1
# 2019-08-28 17:43:34    1
# 2019-10-11 08:34:00    1
# 2019-05-13 07:58:36    1
# 2019-06-25 21:23:48    1
# Name: session_start, Length: 306813, dtype: int64

# %%
visit['session_end'].value_counts()
# Out:
# 2019-08-04 10:32:15    3
# 2019-09-23 20:37:13    3
# 2019-08-03 06:31:26    3
# 2019-09-29 17:32:12    3
# 2019-09-26 08:30:19    3
#                       ..
# 2019-10-27 23:08:22    1
# 2019-08-25 01:02:51    1
# 2019-06-17 02:33:04    1
# 2019-10-16 03:17:54    1
# 2019-05-08 23:10:58    1
# Name: session_end, Length: 306793, dtype: int64

# %% [markdown]
# Количество начатых и завершенных сессий сходится и составляет 309901. По таймингу в одно время максимум осуществлялось  3 сессии использвания сервиса. Всего 306813 и 306793 уникальных начала и конца сессий соответственно.

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
order.head(10)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99

# %% [markdown]
# Преобразуем датафрейм:
# - переведем названия столбцов в нижний регистр
# - Event Dt столбцу присвоим тип datetime вместо object

# %%
order.columns = order.columns.str.lower().str.replace(' ', '_')
order['event_dt'] = pd.to_datetime(order['event_dt'])
# перепроверим себя, вызвав метод info()
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %% [markdown]
# Оценим, есть ли в датафрейме нулевые значения и дупликаты:

# %%
order.duplicated().sum()
# Out:
# 0

# %%
 order.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# Не наблюдаем нулевых значений, отлично.

# %% [markdown]
# Теперь интересно посмотреть на данный датафрейма:
# - оценить минимальное, максимальное, посмотреть на вбросы, а так же среднее и медиану по колонке revenue (заказы)
# - сколько уникальных пользователей (и какие фигурируют чаще всего)
# - сколько уникальных значений заказов

# %%
order['revenue'].describe()
# Out:
# count    40212.000000
# mean         5.370608
# std          3.454208
# min          4.990000
# 25%          4.990000
# 50%          4.990000
# 75%          4.990000
# max         49.990000
# Name: revenue, dtype: float64

# %%
order['user_id'].value_counts()
# Out:
# 901180916748    22
# 883098437811    20
# 75337957494     19
# 512471511263    19
# 295795879965    19
#                 ..
# 237296010927     1
# 319939546352     1
# 742075710598     1
# 202972423389     1
# 775233404832     1
# Name: user_id, Length: 8881, dtype: int64

# %%
order['event_dt'].value_counts()
# Out:
# 2019-09-29 09:03:24    2
# 2019-10-25 16:24:24    2
# 2019-09-27 03:56:55    2
# 2019-08-12 22:50:49    2
# 2019-09-09 20:01:39    2
#                       ..
# 2019-09-26 04:24:10    1
# 2019-10-26 06:25:45    1
# 2019-07-10 17:04:38    1
# 2019-08-06 08:55:42    1
# 2019-09-25 16:41:33    1
# Name: event_dt, Length: 40163, dtype: int64

# %%
order['event_dt'].count()
# Out:
# 40212

# %% [markdown]
# Вывод:
# - оценить минимальное, максимальное, посмотреть на вбросы, а так же среднее и медиану по колонке revenue (заказы): среднее и медиана находятся достаточно близко друг к другу (4,99 и 5,37), максимальная сумма заказа составляет 49,9, а минимальная соответствует медиане 4,99 (могу предположить, что вборсов не много, так как не сильно разнятся значения медианы и среднего. Так же часто повторяется цифра 4,99 - видимо это стоимость подписки на сервис?
# - сколько уникальных пользователей (и какие фигурируют чаще всего): в датафрейме 8881 уникальный пользователь, пользователь с наибльшим количеством покупок имеет идентификационный номер 901180916748 (22 заказа)
# - сколько уникальных значений заказов: строк с уникальным номером заказа 40163, всего заказов 40212

# %%
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
cost.head(10)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %% [markdown]
# В датафрейме cost преборазуем данные о времени в столбце dt, в столбце Channel преобразуем информацию к строковому типу, а так же приведем названия столбцов к нижнему регистру (и проверим себя в конце):

# %%
cost['dt'] = pd.to_datetime(cost['dt'], format="%Y-%m-%d")
cost['Channel'] = cost['Channel'].astype('str')
cost.columns = cost.columns.str.lower().str.replace(' ', '_')
cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB

# %% [markdown]
# Теперь посмотрим на структуру датафрейма:
# - есть ли нулевые значения
# - посмотрим на максимальную, среднюю, медиану, минимальную (и выбросы) стоимость рекламных затрат
# - сколько всего строк с данными о затратах на маркетинг (и сколько уникальных)
# - какие каналы для закупки рекламы фигурируют в датафрейме

# %%
cost.duplicated().sum()
# Out:
# 0

# %%
cost['costs'].describe()
# Out:
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %%
cost['dt'].value_counts()
# Out:
# 2019-10-10    10
# 2019-06-01    10
# 2019-08-30    10
# 2019-10-14    10
# 2019-06-12    10
#               ..
# 2019-05-24    10
# 2019-07-08    10
# 2019-08-22    10
# 2019-10-06    10
# 2019-08-26    10
# Name: dt, Length: 180, dtype: int64

# %%
cost['dt'].count()
# Out:
# 1800

# %%
cost['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Выывод:
# - есть ли нулевые значения: нулевых значений нет
# - посмотрим на максимальную, среднюю, медиану, минимальную (и выбросы) стоимость рекламных затрат: медианное значение и средняя затрата на рекламу отличаются более значительно (12.3 против 58.6), при этом максимальная закупка рекламы обошлась в 630, что похоже на вброс. Минимальная затрата на рекламную кампанию составила 0.8. Более 75% рекламных кампаний обходятся фирме в менее чем 34 уе
# - сколько всего строк с данными о затратах на маркетинг (и сколько уникальных): всего 1800 строк с данными о затратах на маркетинг, из них по датам 180 уникальных строк (собраны данные за 180 дней), в каждой в среднем 10 значений о рекламе
# - какие каналы для закупки рекламы фигурируют в датафрейме: всего 10 каналов

# %% [markdown]
# ## Общий вывод:
# - Я изучила данные о сессиях пользователей, заказах и рекламных затратах, выполнила предобработку. Обнаружила, что в данных нет очевидных дубликатов и пропусков. Скорректировала типы данных, чтобы они соответствовали сохраненным в них значениям (с особенным вниманием к столбцам с датой и временем)
#
# - Всего у нас 150008 уникальных пользователей. В датафреймах имеется информация о пользователях из 4 стран: США, Великобритания, Франция, Германия. Среди данных об устройствах представленно 4 типа гаджетов(iPhone, Android, PC, Mac), наибольшей популярностью сервис пользуется у владельцев iPhone, наименее популярен сервис на Mac.
#
# - В датафрейме заказов у нас 8881 уникальный пользователь, мы даже вычислили идентификационный номер самого часто заказывающего пользователя (901180916748). Мы оценили среднюю стоимость заказа - медиана составляет 4.99, а среднеарифметическое значение 5.37. При этом имеют место вбросы - максимальня сумма заказа составляет 49.99 (может тут имеет место подписка в сервисе)
#
# - В информации о закупке рекламных кампаний мы видим, что всего есть 10 каналов закупки рекламы: 'FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit', 'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner', 'lambdaMediaAds'. Среднее и медиана трат на рекламу сильно разнятся - 58.6 против 12.2 соответственно. Максимальная трата на маркетинг составляет 630 уе, что похоже на вброс, а минимальная затрата 0.8

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# Для функций и дальнейшего анализа датафреймов нам требуется определиться с моментом и горизонтом анализа. Момент анализа 1 ноября 2019 года, а так как заложено в бизнес-плане, что пользователи должны окупаться не позднее чем через две недели после привлечения, то горизонт анализа составит 14 дней.
# Далее мы добавим коды функций для будущего анализа данных.

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'], format="%Y-%m-%d")
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )


    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days


    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)


    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC,
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean()
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Мы задали основные функции, которые дальше нам понадобятся в анализе данных (удержание, конверсия, LTV и ROI)

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Хорошо. Приступим к анализу
#
# </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# Состаляем профили пользователей, определим максимальную и минимальную дату привлечения пользователей (при помози функции get_profiles, передадим ей в качестве аргумента датафреймы visit, order, cost):

# %%
profiles = get_profiles(visit, order, cost)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# В профиле пользователей у нас отражены: идентификационный номер, дата входа, канал привлечения, устройство, с которого пользователь зашел в приложение, а так же наличие отсутсиве покупки и стоимость привлечения;

# %% [markdown]
# Далее определим минимальную и максимальную дату привлечения пользователей:

# %%
min_analysis_date = profiles['dt'].min()
print('Минимальная дата привлечения клиентов:',min_analysis_date)
max_analysis_date = profiles['dt'].max()
print('Максимальная дата привлечения клиентов:',max_analysis_date)
# Out:
# Минимальная дата привлечения клиентов: 2019-05-01 00:00:00
# Максимальная дата привлечения клиентов: 2019-10-27 00:00:00

# %% [markdown]
# Минимальная дата привлечения пользователей - 1 мая 2019 года. Максимальная дата привлечения пользователей - 27 октября 2019 года, что соответствует описанию датафреймов.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Согласен, все по ТЗ
#
# </div>

# %% [markdown]
# Теперь выясним, из каких стран пользователи заходят в сервис и на какую страну приходится больше всего платящих пользователей.
# Для этого построим круговую диаграмму, на которой отобразим:
# - распределение всех пользователей по странам
# - распределение платящих пользователей по странам

# %%
country_payment = profiles.groupby('region').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)



fig1, ax1 = plt.subplots()
ax1.pie(country_payment['user_id'], labels=country_payment.index, autopct='%1.1f%%')
ax1.set_title('Доля всех пользователей по регионам')



fig2, ax2 = plt.subplots()
ax2.pie(country_payment['payer'], labels=country_payment.index, autopct='%1.1f%%')
ax2.set_title('Доля платящих пользователей по регионам')
plt.show()

# %% [markdown]
# Так же выведем данные в таблице (вопрос наглядности - как проще изучать данные):
# - таблица 1 - данные распределения общего количества пользователей по регионам
# - таблица 2 - распределение платящих пользователей по регионам.

# %%
region_users = pd.DataFrame()
region_users['users_cnt'] = profiles.groupby('region')['user_id'].count()
region_users['share'] = ((region_users['users_cnt'] / profiles['region'].count()) * 100)
region_users.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_15922_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >share</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15922_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_15922_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_15922_row0_col1" class="data row0 col1" >66.66%</td>
#             </tr>
#             <tr>
#                         <th id="T_15922_level0_row1" class="row_heading level0 row1" >UK</th>
#                         <td id="T_15922_row1_col0" class="data row1 col0" >17575</td>
# ...

# %%
region_users_paying = pd.DataFrame()
region_users_paying['users_cnt'] = profiles.query('payer == True').groupby('region')['user_id'].count()
region_users_paying['share'] = ((region_users_paying['users_cnt'] / profiles.query('payer == True')['region'].count()) * 100)
region_users_paying.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_de94f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >share</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de94f_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_de94f_row0_col0" class="data row0 col0" >6902</td>
#                         <td id="T_de94f_row0_col1" class="data row0 col1" >77.72%</td>
#             </tr>
#             <tr>
#                         <th id="T_de94f_level0_row1" class="row_heading level0 row1" >UK</th>
#                         <td id="T_de94f_row1_col0" class="data row1 col0" >700</td>
#                         <td id="T_de94f_row1_col1" class="data row1 col1" >7.88%</td>
# ...

# %% [markdown]
# Вывод:
# - большая часть суммарного количества пользователей из США (66,7%), далее Великобритания и Франция (11.72%, 11.63%). Последнее место занимает Германия: тут сервис наименее популярен, общее количество пользователей там составляет 9.99%
# - платящие пользователи: здесь так же лидирует США(77.72% - что интересно, процент выше чем по общим пользователям), далее Великобритания (7.88%) и франция (7.47%), замыкает рейтинг Германия (6.94%)

# %% [markdown]
# Теперь посмотрим, процент платящих пользователей по каждой стране от общего количества пользователей:

# %%
country_payment['percent_payment'] = country_payment['payer']/country_payment['user_id']*100
country_payment
# Out:
#                user_id  payer  percent_payment
# region
# United States   100002   6902         6.901862
# UK               17575    700         3.982930
# France           17450    663         3.799427
# Germany          14981    616         4.111875

# %% [markdown]
# Здесь мы видим, что процент платящих пользователей от общего их числа для каждой страны относительно невысокий. Что интересно, в США он составляет 6.9%, а вот второе место по такой конвертации занимает Германия (4.1%), далее уже Великобритания и Франция.
# Выходит, что В Германии не так много людей используют приложение, но более эффективно конверитруются в платящих пользователей, чем Великобритании и Франции.

# %% [markdown]
# - Выясним, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Тут мы построим круговую диагнамму для определения процентного соотношения пользователей с различных устройств для общего количества пользователей и для платящей аудитории.
#
# - Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства. Посчитаем процент платящих пользователей в зависимости от типа устройства входа.

# %%
device_payment = profiles.groupby('device').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)

fig1, ax1 = plt.subplots()
ax1.pie(device_payment['user_id'], labels=device_payment.index, autopct='%1.1f%%')
ax1.set_title('Устройства пользователей')

fig2, ax2 = plt.subplots()
ax2.pie(device_payment['payer'], labels=device_payment.index, autopct='%1.1f%%')
ax2.set_title('Устройства платящих пользователей')
plt.show()

# %% [markdown]
# - Похоже, что для общего количества пользователей наибольшую группу образуют владельцы IPhone(36%) и Android(23%). Вероятно, на мобильном телефоне приложение сподручнее или удобнее работет, чем на стационарных машинах. Потому что для PC и Mac процент пользователей практически одинаков (по 20%)
#
# - для платящих пользователей ситуация достаточно симметричная: наиболее востребован сервис у владельцев IPhone (38.1% - чуть больше, чем у общего числа пользователей), далее Android (23,1%), Mac(21,5%) и PC(17,3%).
#
# - Видимо осуществлять заказы удобнее на технике с операционными системами apple, так как IPhone и Mac забирают себе больший процент покупателей, чем Android и PC.

# %%
device_payment['percent_payment'] = device_payment['payer']/device_payment['user_id']*100
device_payment
# Out:
#          user_id  payer  percent_payment
# device
# iPhone     54479   3382         6.207897
# Android    35032   2050         5.851793
# PC         30455   1537         5.046790
# Mac        30042   1912         6.364423

# %% [markdown]
# А вот и процент конвертации для каждого устройства из неплатящих в платящих пользователей. Данные так же не велики:
# - наибольший процент конвертации пользователей Mac: 6.36% (1912 человек из 30042 пользователей проводят покупки)
#
# - второе место занимает iPhone: процент платящих составляет 6.21% 3382 из 54479
#
# - третье место занимает Android: процент платящих составляет 5.85% 2050 из 35032
#
# - четвертое место занимает Android: процент платящих составляет 5.04% 1537 из 30455

# %% [markdown]
# - Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Для визуализации каналов привлечения пользователей построим круговую диаграмму для общего количества пользователей и отдельно для платящей аудитории.
#
# - Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения. А так же сформируем таблицу конверсии общего количества пользователей в платящие.

# %%
channel_payment = profiles.groupby('channel').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(channel_payment['user_id'], labels=channel_payment.index, autopct='%1.1f%%')
ax1.set_title('Каналы привлечения пользователей')

fig2, ax2 = plt.subplots(figsize=(10,10))
ax2.pie(channel_payment['payer'], labels=channel_payment.index, autopct='%1.1f%%')
ax2.set_title('Каналы привлечения платящих пользователей')
plt.show()

# %% [markdown]
#  Теперь визуализируем данные в виде таблицы:
#  - отдельно для общего количества пользователей и платящих
#  - таблица с пользователями, которые совершили оплату и уберем органически пришедших клиентов.

# %%
channel_payment = pd.DataFrame()
channel_payment['users_cnt'] = profiles.groupby('channel')['user_id'].count()
channel_payment['share'] = ((channel_payment['users_cnt'] / profiles['channel'].count()) * 100)

channel_payment['payer_users_cnt'] = profiles.query('payer == True').groupby('channel')['user_id'].count()
channel_payment['payer_share'] = ((channel_payment['payer_users_cnt'] / profiles.query('payer == True')['channel'].count()) * 100)

channel_payment.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%', 'payer_share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_0eb41_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >share</th>        <th class="col_heading level0 col2" >payer_users_cnt</th>        <th class="col_heading level0 col3" >payer_share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0eb41_level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_0eb41_row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_0eb41_row0_col1" class="data row0 col1" >37.62%</td>
#                         <td id="T_0eb41_row0_col2" class="data row0 col2" >1160</td>
# ...

# %% [markdown]
# Наибольший процент приходится на органический трафик среди общего количества пользователей(38%). Далее по числу пользователей идут источники FaceBoom (19.43%) и TipTop(13.04%).
#
# Для платящего сегмента пользователей картина отличается. Органический трафик пользователей отходит сильно на второй план: только 13%.  Большинство платящих пользователей пришли через канал FaceBoom (40%), 21% из TipTop.
#
# По остальным каналам распределение равномерное (в районе 3-5%). Самый непопулярный канал для всех сегментов пользователей - это lambdaMediaAds, для платящих клиентов - MediaTornado, интересно, как мы оплачиваем в этих каналах рекламу и какие цифры получим при анализе?)

# %% [markdown]
# ### А теперь исключим органический источник новых клиентов для платящей аудитории и посмотрим, что получится:

# %%
profiles = profiles.query('channel != "organic"')
def pivot_share_result(column, df):
    result = pd.DataFrame()
    result['users_cnt'] = df.groupby(column)['user_id'].count()
    result['users_share'] = ((result['users_cnt'] / df[column].count()) * 100)
    result['payer_users_cnt'] = df.query('payer == True').groupby(column)['user_id'].count()
    result['payer_share'] = ((result['payer_users_cnt'] / result['users_cnt']) * 100)
    return result.sort_values(by='users_share', ascending=False).style.format({'users_share': '{:.2f}%', 'payer_share': '{:.2f}%'})
pivot_share_result('region', profiles)
pivot_share_result('channel', profiles)
# Out:
# <style  type="text/css" >
# </style><table id="T_056ba_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_cnt</th>        <th class="col_heading level0 col1" >users_share</th>        <th class="col_heading level0 col2" >payer_users_cnt</th>        <th class="col_heading level0 col3" >payer_share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_056ba_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_056ba_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_056ba_row0_col1" class="data row0 col1" >31.15%</td>
#                         <td id="T_056ba_row0_col2" class="data row0 col2" >3557</td>
# ...

# %% [markdown]
# Рейнтинг источников новых платящих пользователей:
# - FaceBoom (12.20%)
#
# - AdNonSense(11.34%)
#
# - lambdaMediaAds(10.47%)
#
# Последние места занимают:
# - OppleCreativeMedia (2.71%)
#
# - LeapBob (3.06%)

# %% [markdown]
# Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
#
# Вывод:
# - Мы составили профили пользователей, определили минимальную и максимальную даты привлечения пользователей: для этого мне пригодилась функция get_profiles(), в которую были переданы данные о посещениях, покупках и тратах на рекламу. Определены минимальная и максимальная даты привлечения пользователей. Это 2019-05-01 00:00:00 и 2019-10-27 00:00:00, что соответствует информации в тз.
# -  Узнали, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей: судя по результатам, значительная доля пользователей - это клиенты из США (66.66%). Далее идут примерно равные доли пользователей из Англии и Франции (~ 12%). Меньше всего пользователей из Германии (~ 10%).
#
# - Так же мы построили таблицу, отражающую количество пользователей и долю платящих из каждой страны: мы пришли к выводам, что платящие пользователи из США лидируют (78%), доли платящих из Франции и Англии примерно равны (7-8%), меньше всего платящих пользователей из Германии (~ 7%) Также выявлено, что доля платящих пользователей из США - 6.90%. Среди пользователей из Англии (17575) платящий сегмент составляет 3.98% (700 человек). Примерно такое же соотношение и для пользователей из Франции (3.80% платящих пользователей). Среди пользователей Германии (14981 человека) 616 человек - платящие (это 4.1%).
#
#
# - Мы выделили пул устройств, с помощью которых пользователи заходят в приложение, уточнили, какой рейтинг устройств у платящей аудитории. Построили таблицу, отражающую количество пользователей и долю платящих для каждого устройства:ориентируясь на таблицу, большинство пользователей - это владельцы IPhone (36%) и Android (23%). То есть, клиенты больше пользуются мобильными устройствами, чем ПК. Доли PC и Mac практически одинаковы (по 20%).
#
# Больше всего доля платящих пользователей для устройства Mac: 6.36% (1912 человек) из 30042 платят за продукт.
#
# Среди пользователей iPhone (54479 человек) доля платящих равна 6.21%.
#
# Для пользователей Android (35032 человек) она составляет 5.85%.
#
# Среди пользователей PC (30455) платящих меньше всего - 5.05% (1537 человек).
#
#
# - Так же мы исследовали рекламные источники привлечения и выявили каналы, из которых пришло больше всего (и меньше всего) платящих пользователей. Если посмотреть на разбивку по источникам привлечения для общего количества пользователей, то мы увидим, что больше всего приходится на органический трафик (38%), далее по числу пользователей идут источники FaceBoom (19%) и TipTop(13%).
#
# Большинство платящих пользователей приходится на каналы
# 1. FaceBoom (12.20%)
#
# 2. AdNonSense(11.34%)
#
# 3. lambdaMediaAds(10.47%)
#
# Последние места занимают:
# 1. OppleCreativeMedia (2.71%)
#
# 2. LeapBob (3.06%)

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# ### Считаем общую сумму расходов на маркетинг и выясним, как траты распределены по рекламным источникам и визуализируем выводы в виоде столбчатой диаграммы:

# %%
cost['costs'].sum()
# Out:
# 105497.30000000002

# %% [markdown]
# Общая сумма затрат на рекламу составила 105497.30000000002 уе

# %%
profiles.groupby('channel').agg({'acquisition_cost': 'sum'})\
.sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22

# %%
params = {'ytick.labelsize': 20,
          'axes.titlesize': 15}
plt.rcParams.update(params)
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])
(
    profiles.groupby('channel').agg({'acquisition_cost': 'sum'})
    .sort_values(by='acquisition_cost')
    .plot(kind= 'barh', figsize=(19,6), legend = False,  grid=True)
)
plt.xlabel('Затраты на рекламу', fontsize=20)
plt.ylabel('Канал привлечения', fontsize=20)
plt.title('Затраты на рекламу по каналу привлечения');

# %% [markdown]
# Мы видим огромные расходы на рекламу Тiptop: на них приходится практически половина всех расходов на рекламу, при этом они приносят 1878 платящих пользователей или 9.60%. Очень интересно узнать, чем обоснованы такие траты на маркетинг именно по этому каналу.
# Еще один канал с наибольшей суммой затрат на рекламу Faceboom, они приносят около 3557 платящих пользователей или 12.20%(почти в два раза больше, чем Тiptop), а затраты в полтора раза ниже на закупку рекламы -32445.60 против 54751.30.
# Затраты на привлечение пользователей с оставшихся каналов значительно ниже и не превышают 6000$

# %% [markdown]
# ### Теперь построим график изменения стоимости маркетинга с течением времени, сначала посмотрим в целом, какая существует динамика:

# %%
cost.plot(y='costs',
           x='dt',
           figsize=(15, 10),
           grid=True,
           rot=45,
           label='Расходы на маркетинг',
           legend=True,
           colormap='Set1')

plt.title('График изменения расходов на маркетинг')
plt.xlabel('Дата')
plt.ylabel('Траты')
plt.show()

# %% [markdown]
# Отлично видно, что увеличение расходов на рекламу с течением времени увеличивается. Во второй половине сентября - начале октября они достигли  пикового значения в  в 630 уе, после чего стали падать до 400, а затем к концу октября внось стремились к 600. Неужели к проекту подключились инвесторы или сильно перераспределился бюджет?

# %% [markdown]
# ### Теперь оценим динамику изменения расходов во времени: по неделям и месяцам по каждому источнику:

# %%
cost['month'] = cost['dt'].astype('datetime64[M]')
cost['week'] = cost['dt'].astype('datetime64[W]')
columns = ['month', 'week']
plt.subplots(figsize = (20,7))
for i, col in enumerate(columns):
    cost.pivot_table(index = col, columns = 'channel', values = 'costs', aggfunc = 'sum').plot.area(ax = plt.subplot(1, 2, i + 1))
    plt.title(col)
    plt.xlabel('Дата')
    plt.ylabel('Расходы на рекламу')

plt.show()

# %% [markdown]
# На графиках хорошо видны наиболее высокобюджетные каналы привлечения: TipTop и FaceBoom. Больше всего трафика закупали у TipTop и к октябрю число трат приближалось к 650 уе.  Число трат на FaceBoom находится в районе 300. Остальные каналы рекламы не показывают высокую динамику по увеличению бюджета, но затраты на TipTop вырастают как раз в сентябре- октябре.
# Мне не нравится визуализация, такой график достаточно тяжело читать. Попробуем другие варианты визуализации:

# %%
# %matplotlib inline

profiles.pivot_table(
    index='dt',
    columns='channel',
    values='acquisition_cost',
    aggfunc='sum'
).plot(figsize=(20, 10), grid=True)
plt.title('График изменения затрат на маркетинг по каналу привлечения')
plt.xlabel('Дата', fontsize=20)
plt.ylabel('Затраты', fontsize=20)
plt.show()

# %% [markdown]
# Стало лучше, но на графике все линии, которые близки к нулевым затратам, сливаются в одну. Здесь лучше видна динамика по наиболее высокозатратным маркетинговым каналам. Теперь детализируем график для значений, которые блики к нулевой отметке.

# %%
profiles.query('channel != ["TipTop", "FaceBoom"]').pivot_table(
    index='dt',
    columns='channel',
    values='acquisition_cost',
    aggfunc='sum'
).plot(figsize=(20, 10), grid=True)
plt.title('График изменения затрат на маркетинг по каналу привлечения')
plt.xlabel('Дата', fontsize=20)
plt.ylabel('Затраты', fontsize=20)
plt.show()

# %% [markdown]
# Рассматривая остальные источники коммерческого привлечения клиентов, помимо TipTop и FaceBoom с июня начали расти траты на WahooNetBanner (к октябрю их число было в районе 53).
# Бюджет на AdNonSense, наоборот, стал снижаться с июня 2019 года (с 55 до 35). По остальным источникам траты варьируются в пределах 3-20.

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя. Рассчитаем средний CAC на одного пользователя для всего проекта.

# %% [markdown]
# сначала напомним себе структуру датафрейма profiles, затем сформируем таблицу привлечения пользователя для каждого канала маркетинга, а дальше визуализируем информацию на графиках.

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel   device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom   iPhone  United States
# 3  22593348 2019-08-22 21:35:48  AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit   iPhone  United States
# 7  46006712 2019-06-30 03:46:29  AdNonSense  Android         France
#
#           dt      month  payer  acquisition_cost
# 0 2019-05-07 2019-05-01   True          1.088172
# 1 2019-07-09 2019-07-01  False          1.107237
# 3 2019-08-22 2019-08-01  False          0.988235
# 4 2019-10-02 2019-10-01  False          0.230769
# 7 2019-06-30 2019-06-01   True          1.008000

# %%
 cost_mean = profiles.groupby('channel').agg({'acquisition_cost': 'mean'})\
.sort_values(by='acquisition_cost', ascending=False).reset_index()
cost_mean
# Out:
#               channel  acquisition_cost
# 0              TipTop          2.799003
# 1            FaceBoom          1.113286
# 2          AdNonSense          1.008054
# 3      lambdaMediaAds          0.724802
# 4      WahooNetBanner          0.602245
# 5      RocketSuperAds          0.412095
# 6  OppleCreativeMedia          0.250000
# 7             YRabbit          0.218975
# 8        MediaTornado          0.218717
# 9             LeapBob          0.210172

# %%
plt.figure(figsize=(20,7))
plt.title('Средняя цена привлечения пользователей')
sns.barplot(data=cost_mean, x='channel', y='acquisition_cost')
plt.xlabel('Канал привлечения', fontsize=20)
plt.ylabel('Средняя стоимость привлечения', fontsize=20);

# %% [markdown]
# Дороже всего  привлечение пользователей из канала TipTop(стоимость - 2.80 за пользователя), около половины бюджета на рекламу приходится на этот канал (при меньшей эффективности, чем у FaceBoom).
# Пользователи из канала FaceBoom и AdNoneSense обходятся в среднем в 1$.
# Все интереснее, с чем связаны такие необосновано высокие траты на привлечение клиентов через TipTop. Трафик остальных каналов стоит в пределах от 0.21 до 0.72.

# %% [markdown]
# ### Вывод:
# - Бюджет маркетинга за исследуемый период составляет 105497.3.
#
# - Распределение трат по источникам: Больше всего трат приходитя на источник TipTop (52%). Следом идет источник FaceBoom(31%). Далее идут низкозатратные источники WahooNetBanner (5%), AdNonSense (4%), OppleCreativeMedia (2.%). На оставшиеся источники приходится 1-2% трат.
#
# - Визуализация изменения метрик маркетинга во времени (за исследуемый период):  Заметны два "активных игрока" - это TipTop и FaceBoom. Больше всего трафика закупали у TipTop, и к октябрю число трат приближалось к 650. Число трат на FaceBoom находится в районе 300. Остальные каналы привлечения обходятся довольно дешево.
#
# - Среди рекламных источников помимо TipTop и FaceBoom с июня начали расти траты на WahooNetBanner (концу сентября-октябрю их число было в районе 53 ). Затраты на AdNonSense стали снижаться с июня 2019 года (с 55 до 35). По остальным источникам траты варьируются в пределах 3-20.
#
# - Мы определили, сколько в среднем стоило привлечение одного пользователя из каждого источника: дороже всего  привлечение пользователей из канала TipTop(стоимость - 2.80 за пользователя), около половины бюджета на рекламу приходится на этот канал (при меньшей эффективности, чем у FaceBoom).
# Пользователи из канала FaceBoom и AdNoneSense обходятся в среднем в 1$.Все интереснее, с чем связаны такие необосновано высокие траты на привлечение клиентов через TipTop. Трафик остальных каналов стоит в пределах от 0.21 до 0.72.
#
# Самый дорогой трафик - TipTop (средняя стоимость - 2.80 за пользователя), а в динамике бюджет  на TipTop составлял около 650, далее идет FaceBoom и AdNonSense примерно в равной ценовой категории (1.11 и 1.01 соответственно). Остальные каналы берут за пользователя от 0.21 до 0.72 у.е.

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Вернемся к заданному горизонту данных (14 дней) и моменту анализа (1 ноября 2019).
# - Избавимся от "органических" пользователей, так как они могут исказить наши показатели при дальнейшем анализе.

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# посчитаем LTV и ROI, визуализируем данные на графике:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# 1. LTV стабильно идёт вверх, значит прибыль с каждого клиента возрастает на протяжении всего "лайфтайма" (тут может влиять фактор сезонности, но может быть падает качество пользователей, судя по значениям ROI и CAC?)
# 2. Реклама не окупается к концу 2й недели. ROI — около 80%. ROI пользователей неумолимо падает(до июля показатель был выше уровня окупаемости, но после стал падать до 0.6)
# 3. Показатель САС на протяжении всего периода  растёт, в то время как показатель ROI стабильно идёт вниз: CAC нестабилен. Рекламный бюджет увеличивается с течением времени.

# %% [markdown]
# Визуализируем общую конверсию пользователей, динамику изменения, удержание пользователей. Изучим графики конверсии и удержания.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days)


plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Пользователи конвертируются неплохо первые 4 дня "жизни", далее конверсия тоже растёт, но уже незначительными темпами.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей на первый день лайфтайма составляет менее 40%, в то время, как неплатящие пользователи не задерживаются в приложении.
# К 12-14 дню остается всего 10% платящих клиентов.
# Через 14 дней по динамике удержания остается в среднем от 7 до 12% пользователей.
# Самое высокое удержание на 14ый день наблюдалось июне- 17%.

# %% [markdown]
# Анализ окупаемости рекламы с разбивкой по устройствам (воспользуемся функцией get_ltv):

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# LTV клиентов не зависимо от устройства растет стабильно. Ниже всего показатель у покупателей с PC, однако окупается именно эта категория, ROI выше чем у клиентов остальных устройств. Наиболее высокие затраты на привлечение пользователей Mac и iPhone (тут при высокой стоимости привлечения страдает окупаемость). В целом как будто наблюдается некоторая сезонность показателя LTV, однако показатель стабилен.
# До июня окупаемость не зависимо от устройства возрастала, однако особенно для владельцев Mac и iPhone стала падать (может быть что то случилось с приложением? или была какая-то селективная акция?)
# В сентябре ушла в минус окупаемость всех устройств.

# %% [markdown]
# Теперь посмотрим конверсию с разбивкой по устройствам. Нам понадобятся функции get_conversion() и plot_conversion():

# %%
 dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Ориентируясь на визуализацию на графиках, хорошо конвертируются клиенты, использующие Mac, Android и iPhone (хуже дела обстоят с PC), причем на протяжении длительного времени. Дело может быть в коротком удержании клиентов, для этого оценим удержание (=ретенцию) клиентов в приложении:

# %% [markdown]
# смотрим удержание с разбивкой по устройствам (для этого вызовем  функции get_retention() и plot_retention()):

# %%
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Как будто не видны прогалы в удержании пользователей (совершивших покупку) каких то определенных устройств.
# Неплатящие пользователи удерживаются стабильно плохо.
# Из клиентов, совершивших покупку лучше всего удерживаются пользователи PC, хуже - владельцы iPhone и Mac.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Согласен
#
# </div>

# %% [markdown]
# Анализиурем окупаемость с разбивкой по странам (используем функцию get_ltv и для визуализации plot_ltv_roi):

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - уровень окупаемости рекламы не одинаковый в разных локациях. При самой высокой стоимости привлечения покупателей там наиболее низкая окупаемость маркетинговых программ. САС в США стремительно растет, а ROI значительно ниже, чем в других регионах, при том, что пользователи США имеют значительную "пожизненную ценность".
#
# - как будто по месяцам ROI стал падать ниже 1.0 тогда, когда стал возрастать бюджет маркетинговых компаний. Может быть в этот момент у компании возник конкурент в тех же регионах? или неудачное обновление продукта? Факт следующий - сервис теряет свою привлекательность для пользователей.
#
# - LTV достаточно стабилен, растет.
#
# - в Великобритании и Германии окупается привлечение клиентов.

# %% [markdown]
# Посчитаем и визуализируем конверсию, используя функции get_conversion() и plot_conversion()
# Оценим конверсию с разбивкой по странам:

# %%
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# У США наиболее высокая конверсия клиентов. В динамике к концу мая конверсия Германии, Великобритании и Франции превышает конверсию пользователей из США. Далее взлетов конверсии не наблюдаем.

# %% [markdown]
# Оценим удержание с разбивкой по странам, воспользуемся функциями get_retention и plot_retention:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Опять сложности с пользователями из США - они хуже удерживаются и траты на маркетинг в данном регионе не окупается.

# %% [markdown]
# Проанализируем окупаемость рекламы с разбивкой по рекламным каналам при помощи функций get_ltv и plot_ltv_roi:

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Видим большой рост стоимости привлечения пользователей из рекламного канала TipTop. Достаточно много средств было потрачено на эту рекламную сеть,но реальные результаты ниже ожидаемых. Не окупаются пользователи, привлеченные из каналов LeapBop, FaceBoom, TipTop, AdNoneSense (похоже, что они не переходили порог окупаемости за весь анализируемый период). Хорошо показала себя рекламная сеть YRabbit в июле - ROI пользователей на 14 день был высок.
#
#
# Окупаемость пользователей, привлечённых с других каналов (кроме TipTop и FaceBoom), во многом показывает высокую рентабельность, стоит обратить на них внимание: в первую очередь, это:  YRabbit, LambdaMediaAds, MediaTornado.

# %% [markdown]
# Определим конверсию с разбивкой по каналам привлечения:

# %%
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Плохо конвертируются пользователи из каналов OppleCreativeMedia, MediaTornado, YRabbit, LeapBob, RocketSuperAds.
# График конверсии клиентов из LambdaMediaAds очень нестабилен: на кривой видны резкие взлеты и падения в разные периоды.

# %% [markdown]
# Смотрим удержание с разбивкой по каналам привлечения клиентов:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Пользователи с каналов AdNoneSense и Фэйсбум также удерживаются хуже всего, поэтому стоит пересмотреть бюджет на маркетинг в этих компаниях или поменять тип монетизации рекламы?

# %% [markdown]
# ВЫВОД:
# По проведенным исследованиям можно сказать, что реклама почти окупается к концу 2й недели, ROI — около 80%
# Окупаемость могут снижать клиенты, использующие  Mac и iPhone, страна - США имеет наиболее высокую стоимость привлечения клиентов и небольшой процент оставаемости.
# Вероятно следует пересмотреть бюджет на маркетинг в рекламных кампаниях каналов LeapBop, FaceBoom, TipTop в связи с низкой эффективностью привлечения покупателей.
# Очень интересно посмотреть, почему неравномерно распределен бюджет на маркетинг: в какой-то источник вложено больше средств, чем в остальные, а он не оправдал надежд.
# В целом, реклама близка к окупемости, если учитывать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения( однако возможно, что горизонт анализа недостаточен для того, чтобы пользователи окупились).

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# ##### Причины неэффективности привлечения пользователей:
# Факторы, влияющие на низкую окупаемость привлеченных покупателей:
# 1. ROI — около 80%
# 2. CAC нестабилен
# 3. Возрастание рекламного бюджета с течением времени (несоразмеренно с окупаемостью привлеченных пользователей)
#
#
# - LTV растет, но пристутсвует некоторая сезонность в кривой роста данного фактора, однако показатель достаточно стабилен.
#
# - Скорее всего качество пользователей не ухудшается, но ROI пользователей продолжает падать. До июля индекс был выше уровня окупаемости, но с течением времени кривая графика стала стремиться к отметке 0.6. Мы перебрали все характеристики для того, чтобы с разных сторон рассмотреть данную проблему (страна, канал привлечения или же устройство, с которого пользователь заходит в сервис и совершает покупки).
#
# - Оценка по устройству входа:
# До конца июня хорошо окупались все пользователи, не зависимо от устройства входа в приложение. С июля стала падать окупаемость, особенно для владельцев Mac и Iphone. В августе и сентябре ROI пользователей ПК был на грани окупаемости, в то время как у владельцев другого типа гаджетов был уже ниже заданного уровня начиная с конца июня.
# LTV стабилен, но подверхен сезонности, вероятно. По стоимости привлечения: самая низкая у ПК, в то время, как ROI выше остальных.
# За рассматриваемый период росла стоимость привлечения новых пользователей.
#
# Внимание остановить стоит на пользователях Mac и Iphone, так как у них небольшая окупаемость, но растущая стоимость привлечения.
# Мы посчитали и визуализировали конверсию: судя по кривым графика, она находится в хорошем диапазоне у пользователей Android, Mac и iPhone, причем на протяжение длительного периода наблюдения. Вероятно, проблема кроется в удержании, однако после построения графиков кривых удержания и здесь мы не нашли явных проблем.
# Стабильно плохо удерживаются неплатящие пользователи, а из покупателей дольше всего удерживаются пользователи PC, наименьшее удержание во времени показали владельцы Mac и iPhone.
#
# - Разбивка по странам:
# Значительная доля клиентов из США (66.7%).
# Далее равные доли пользователей из Великобритании и Франции (~ по 12%). Меньше всего пользователей из Германии (около 10%)
# Платящие пользователи из США лидируют (78%), доли платящих из Франции и Англии примерно равны (7-8%), меньше всего платящих пользователей из Германии (около 7%).
#
# - Из графики:
#
# Маректинг имеет неравномерную окупаемость по регионам.
# Низкий уровень окупаемости в США, при высокой стоимости привлечения новых покупателей. Однако пользователи США и являются основной аудиторией
# Окупаемость пользователей начала падать с конца июня 2019 года.
# Возможно,запуск похожего продукта у конкурентов, неудачный релиз, или какие-то изменения в продукте сыграли отрицательную роль.
# Лучше всего окупается Англия и Германия.
# Слабая конверсия у пользователей из Англии, Германии и Франции. Их доля относительно всех пользователей не велика.
#
# - Разбивка по каналам:
#
# Колоссальный рост стоимости привлечения пользователей из рекламного канала TipTop. По какой-то причине много средств было потрачено на эту рекламную сеть, но итога получилось не так много, как ожидалось.
# Низкую окупаемость имеют пользователи, привлеченные из каналов LeapBop, FaceBoom, TipTop.
# На фоне этого хорошо показала себя рекламная сеть YRabbit в июле - ROI пользователей на 14 день был высок.
# Плохо конвертируются пользователи из каналов MediaTornado, RocketSuperAds, YRabbit.
# Явные аутсайдеры по удерживанию - пользователи из каналов  AdNonSense, FaceBoom.
#
#
# ##### Рекомендации для отдела маркетинга для повышения эффективности
# 1. При анализе разбивки клиентов по устройствам: владельцы Mac и iPhone и Android имеют высокую и при этом растущую стоимость привлечения, а при этом страдающую окупаемость. Больше всего доля платящих пользователей для устройства Mac: 6.4% (1912 человек) из 30042 совершают покупки.Среди пользователей iPhone (54479 человек) доля покупателей равна 6.2%. Для пользователей Android (35032 человек) она составляет 5.9%.Среди пользователей PC (30455) платящих меньше всего - 5% (1537 человек)).
# Вероятно можно рассмотреть какой то маркетинговый маневр для владельцев наиболее прибыльных по оплате устройств для повышение уровня прибыли.
# Какие устройства наиболее популярны среди платящих пользователей:
# - IPhone (36%) - 54479 человек,  доля платящих равна 6.21%.
# - Android (23%) - 35032 человек, доля платящих равна 5.85%
# Покупатели больше пользуются мобильными устройствами, чем ПК (возможно, изучаемый сервис больше адаптирован под мобильные устройства). Доли PC и Mac практически одинаковы (по 20%). Возможно имеет смысл лучше адаптировать работу сервиса под пк и Mac для увеличение процента клиентов со стационарных машин.
#
# 2. По регионам мы выяснили, что лучше всего окупается Англия и Германия (среди пользователей из Англии (17575) платящий сегмент составляет 3.98% (700 человек), но примерно такое же соотношение имеет и Франция: 3.80% платящих пользователей. Среди пользователей Германии (14981 человека) 616 человек - платящие (это 4.1%)) Возможно, стоит локализовать маркетинговые программы для этих регионов, чтобы расширить аудиторию.
#
# 3. По региону Америки: покупатели из США занимают лидирующее место(78%), но при этом являются аутсайдерами по окупаемости. По какой-то причине с конца июня стала падать окупаемость новых пользователей, возможно сервис стал менее привлекательным или появились более выгодные предложения на рынке от компаний-конкурентов. Важно было бы подробнее исследовать, что послужило причиной такого падения окупаемости, основная аудитория приложения это пользователи из Америки.
#
# 4. По каналам привлечения клиентов:
# - приоритетные: FaceBoom (12.20%), AdNonSense(11.34%) и lambdaMediaAds(10.47%)
# - наименее приоритетные: OppleCreativeMedia (2.71%) и LeapBob (3.06%)
# Мы видим на графиках значительный рост стоимости привлечения пользователей из рекламного канала TipTop. Маркетинговый бюджет данного канала внушительный, но стоит рассмотреть уменьшение бюджета, выделяемого на эту сеть и перенаправление его на более эффективный канал из-за низкой эффективности и привлекательности канала для новых клиентов.
#
# - Хуже всех удерживаются пользователи из каналов FaceBoom и AdNonSense.
#
# - Наиболее высокий бюджет маркетинга у TipTop, к октябрю число трат приближалось к 650 у.е., число трат на FaceBoom находится в районе 300.
#
# Возможно стоило бы рассмотреть переключение внимания на более дешевые, но прибыльные каналы, тк остальные каналы привлечения обходятся довольно дешево.
#
# не окупаются пользватели, привлеченные из каналов LeapBop, FaceBoom, TipTop (больше всего трафика закупали у TipTop, соответственно к октябрю число трат приближалось к 650 у.е., число трат на FaceBoom находится в районе 300), а остальные каналы привлечения обходятся довольно дешево (хуже всех удерживаются пользователи из каналов FaceBoom и AdNonSense),то стоило бы рассмотреть переключение внимания на более дешевые, но прибыльные каналы.
#
# Так же стоит рассмотреть возможности социальных сетей - так как это динамично развивающийся источник привлечения новых пользователей, имеющий большой охват аудитории и относительно невысокую стоимость.
#
# Еще можно повысить удержание для пользователей из США, например с помощью введения персонализированных UX-стратегий, e-mail рассылок, персональных рекомендаций, push-уведомлений. Можно ввести определённые "награды" или привилегии для постоянных пользователей. Для канала FaceBoom можно настроить более таргетированное привлечение, направленное на пользователей с необходимыми характеристиками. Также, можно ввести поощрение пользователей за репосты контента и прочий социальный engagement, связанный с приложением, в данном канале.
